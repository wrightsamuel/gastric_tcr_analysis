# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import seaborn as sns

# %%
adata = sc.read_h5ad('/home/jupyter/data/ge_korea/results/ge_korea_b_annotation.h5ad')

# %%
sc.pl.umap(adata,color='annot_3rd')
# Out:
# /home/jupyter/mambaforge/envs/python38/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
pd.DataFrame(adata.obsm['X_umap'],index=adata.obs_names).to_csv('/home/jupyter/data/ge_korea/notebooks_2025/manuscript_nbs/misc_data/b_cell_umap.csv')
